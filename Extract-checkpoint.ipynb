# %%
# !pip install azure-storage-blob
# !pip install pandas sqlalchemy psycopg2

# %%
import pandas as pd
import numpy as np
import requests
import json
from io import StringIO
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from sqlalchemy import create_engine

# %%
CONNECTION_STRING_AZURE_STORAGE = "DefaultEndpointsProtocol=https;AccountName=stcis4400group5;AccountKey=OkQ72k34TrNrha7h9986q+Vc7IBZ/h1bJ/0a2Au1MaZeVSojchUHUxY9uO9mBOK1FrUShCqkFmP2+AStUmii2A==;EndpointSuffix=core.windows.net"
CONTAINER_AZURE = 'ppploans'

urls = [
    "https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/738e639c-1fbf-4e16-beb0-a223831011e8/download/public_150k_plus_230930.csv",
    "https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/a7fa66f4-fd2e-433c-8ef9-59780ef60ae5/download/public_up_to_150k_1_230930.csv",
    "https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/7d2308a8-0ac1-48a8-b21b-f9eb373ac417/download/public_up_to_150k_2_230930.csv",
    "https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/5158aae1-066d-4d01-a226-e44ecc9bdda7/download/public_up_to_150k_3_230930.csv",
    "https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/d888bab1-da5b-46f2-bed2-a052d48af246/download/public_up_to_150k_4_230930.csv",
    "https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/ee12d751-2bb4-4343-8330-32311ae4e7c7/download/public_up_to_150k_5_230930.csv",
    "https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/27b874d9-a059-4296-bb74-374294c48616/download/public_up_to_150k_6_230930.csv",
    "https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/434efae0-016a-48da-92dc-c6f113d827c1/download/public_up_to_150k_7_230930.csv",
    "https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/4fc8e993-c3b9-4eb2-b9bb-dfbde9b1fb6f/download/public_up_to_150k_8_230930.csv",
    "https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/7f9c6867-2b55-472e-a4f3-fd0f5f27f790/download/public_up_to_150k_9_230930.csv",
    "https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/a8f2c8b2-facb-4e97-ad5f-7c8736c8b4b6/download/public_up_to_150k_10_230930.csv",
    "https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/6f9787a3-afd6-45b2-b78e-ad0dc097c1c3/download/public_up_to_150k_11_230930.csv",
    "https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/b6528428-fbd9-4ca6-ae08-9e3416f8ee7f/download/public_up_to_150k_12_230930.csv"
]

blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

for idx, url in enumerate(urls):
    response = requests.get(url)
    if response.status_code == 200:
        df = pd.read_csv(StringIO(response.text), low_memory=False)  # Add low_memory=False here
        blob_name = f"ppploans{idx}_230930.csv"  # Concatenate index with string 'ppploans'
        blob_client = blob_service_client.get_blob_client(container=CONTAINER_AZURE, blob=blob_name)
        blob_client.upload_blob(df.to_csv(index=False), overwrite=True)
        print(f"Uploaded {blob_name} to Azure Blob Storage in container {CONTAINER_AZURE}.")
    else:
        print(f"Failed to fetch data from {url}. Status code: {response.status_code}")

# %%
database_url = "postgresql://cis4400group5:baruch$123@dwcis4400group5.postgres.database.azure.com:5432/postgres"
engine = create_engine(database_url)
CONNECTION_STRING_AZURE_STORAGE = "DefaultEndpointsProtocol=https;AccountName=stcis4400group5;AccountKey=OkQ72k34TrNrha7h9986q+Vc7IBZ/h1bJ/0a2Au1MaZeVSojchUHUxY9uO9mBOK1FrUShCqkFmP2+AStUmii2A==;EndpointSuffix=core.windows.net"
CONTAINER_AZURE = 'ppploans'

def load_csv_from_blob_to_db(blob_name, table_name, engine):
    blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)
    blob_client = blob_service_client.get_blob_client(container=CONTAINER_AZURE, blob=blob_name)
    blob_data = blob_client.download_blob()
    blob_content = blob_data.readall().decode('utf-8')
    df = pd.read_csv(StringIO(blob_content), low_memory=False)
    df.to_sql(table_name, engine, if_exists='append', index=False)
    print(f"Inserted {len(df)} rows into {table_name} from {blob_name}")
blob_names = [
    "ppploans0_230930.csv",
    "ppploans1_230930.csv",
    "ppploans2_230930.csv",
    "ppploans3_230930.csv",
    "ppploans4_230930.csv",
    "ppploans5_230930.csv",
    "ppploans6_230930.csv",
    "ppploans7_230930.csv",
    "ppploans8_230930.csv",
    "ppploans9_230930.csv",
    "ppploans10_230930.csv",
    "ppploans11_230930.csv",
    "ppploans12_230930.csv"
]
table_name = "ppp_loans_data"
for blob_name in blob_names:
    load_csv_from_blob_to_db(blob_name, table_name, engine)

# %%
database_url = "postgresql://cis4400group5:baruch$123@dwcis4400group5.postgres.database.azure.com:5432/postgres"
engine = create_engine(database_url)
CONNECTION_STRING_AZURE_STORAGE = "DefaultEndpointsProtocol=https;AccountName=stcis4400group5;AccountKey=OkQ72k34TrNrha7h9986q+Vc7IBZ/h1bJ/0a2Au1MaZeVSojchUHUxY9uO9mBOK1FrUShCqkFmP2+AStUmii2A==;EndpointSuffix=core.windows.net"
CONTAINER_AZURE = 'gdpbycounty'
def load_csv_from_blob_to_db(blob_name, table_name, engine):
    blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)
    blob_client = blob_service_client.get_blob_client(container=CONTAINER_AZURE, blob=blob_name)
    blob_data = blob_client.download_blob()
    blob_content = blob_data.readall().decode('latin1')
    df = pd.read_csv(StringIO(blob_content), low_memory=False)
    df.to_sql(table_name, engine, if_exists='append', index=False)
    print(f"Inserted {len(df)} rows into {table_name} from {blob_name}")
blob_names = [
    "CAGDP2__ALL_AREAS_2017_2022.csv"
]
table_name = "gdp_by_county_data"
for blob_name in blob_names:
    load_csv_from_blob_to_db(blob_name, table_name, engine)

# %%
##Cleaningup

# %%
def transform_data(ppp_covid_df):
  try:
    df_raw['DateApproved'] = pd.to_datetime(df_raw['DateApproved'])
    df_raw['LoanStatusDate'] = pd.to_datetime(df_raw['LoanStatusDate'])
    df_raw['ForgivenessDate'] = pd.to_datetime(df_raw['ForgivenessDate'])
    categorical_cols = ['BorrowerName', 'BorrowerAddress', 'BorrowerCity', 'BorrowerState', 'BorrowerZip',
                    'ProjectCity', 'ProjectCountyName', 'ProjectState', 'ProjectZip', 'CD', 'BusinessAgeDescription',
                    'FranchiseName', 'NAICSCode', 'NonProfit']
    df_raw[categorical_cols] = df_raw[categorical_cols].fillna('Unknown')
  except Exception as e:
      print("An error occurred during data transformation:", str(e))
      return None

transformed_df = transform_data(ppp_covid_df)
transformed_df.head()

# %%
# Convert date columns to datetime objects
df_raw['DateApproved'] = pd.to_datetime(df_raw['DateApproved'])
df_raw['LoanStatusDate'] = pd.to_datetime(df_raw['LoanStatusDate'])
df_raw['ForgivenessDate'] = pd.to_datetime(df_raw['ForgivenessDate'])

df_raw.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   2020-05-01            464              PPP
# 1  9777677704   2020-05-01            464              PPP
# 2  5791407702   2020-05-01           1013              PPP
# 3  6223567700   2020-05-01            920              PPP
# 4  9662437702   2020-05-01            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate  ...             BusinessType  \
# 0           NaN  29150-9662     2020-12-18  ...              Corporation
# ...

# %%
categorical_cols = ['BorrowerName', 'BorrowerAddress', 'BorrowerCity', 'BorrowerState', 'BorrowerZip',
                    'ProjectCity', 'ProjectCountyName', 'ProjectState', 'ProjectZip', 'CD', 'BusinessAgeDescription',
                    'FranchiseName', 'NAICSCode', 'NonProfit']
df_raw[categorical_cols] = df_raw[categorical_cols].fillna('Unknown')

# %%
numerical_cols = ['UndisbursedAmount', 'UTILITIES_PROCEED', 'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED',
                  'RENT_PROCEED', 'REFINANCE_EIDL_PROCEED', 'HEALTH_CARE_PROCEED', 'DEBT_INTEREST_PROCEED',
                  'ForgivenessAmount', 'JobsReported', 'SBAGuarantyPercentage']
df_raw[numerical_cols] = df_raw[numerical_cols].fillna(df_raw[numerical_cols].mean())

df_raw.head()
